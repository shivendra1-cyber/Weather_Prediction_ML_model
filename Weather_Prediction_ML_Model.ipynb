# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendra1-cyber/Weather_Prediction_ML_model/blob/main/Weather_Prediction_ML_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
weather = pd.read_csv("local_weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2022-01-24  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-25  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-26  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-27  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
# ...

# %%
weather.loc['1960-01-01':'1960-01-31',:]
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-06  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-07  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-08  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-09  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-10  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-11  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-12  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...

# %% [markdown]
# as missing value are none of use for machine learning model we need to remove them at all

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.653360
# ACSH       0.653360
# AWND       0.522451
# DAPR       0.999525
# FMTM       0.870099
# FRGT       0.999881
# MDPR       0.999525
# PGTM       0.495106
# PRCP       0.016668
# SNOW       0.324990
# SNWD       0.317634
# TAVG       0.879174
# TMAX       0.000534
# TMIN       0.000593
# TSUN       0.931728
# WDF1       0.653360
# WDF2       0.522392
# WDF5       0.527552
# WDFG       0.746901
# WSF1       0.653360
# WSF2       0.522332
# WSF5       0.527552
# WSFG       0.746901
# WT01       0.779939
# WT02       0.980248
# WT03       0.992941
# WT04       0.999763
# WT05       0.998339
# WT07       0.999881
# WT08       0.810368
# WT09       0.999881
# WT16       0.884038
# WT18       0.999822
# dtype: float64

# %%
core_weather=weather[['PRCP','SNOW','SNWD','TMAX','TMIN']].copy()

# %%
core_weather
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1960-01-01   0.0   0.0   0.0  49.0  30.0
# 1960-01-02   0.0   0.0   0.0  49.0  29.0
# 1960-01-03   0.0   0.0   0.0  54.0  35.0
# 1960-01-04   0.0   0.0   0.0  54.0  36.0
# 1960-01-05   0.0   0.0   0.0  55.0  33.0
# ...          ...   ...   ...   ...   ...
# 2022-01-24   0.0   NaN   NaN  60.0  39.0
# 2022-01-25   0.0   NaN   NaN  57.0  43.0
# 2022-01-26   0.0   NaN   NaN  57.0  41.0
# 2022-01-27   0.0   NaN   NaN  67.0  39.0
# 2022-01-28   0.0   NaN   NaN  64.0  39.0
#
# [16859 rows x 5 columns]

# %%
core_weather.columns=['precip','snow','snow_depth','temp_max','temp_min']

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01     0.0   0.0         0.0      49.0      30.0
# 1960-01-02     0.0   0.0         0.0      49.0      29.0
# 1960-01-03     0.0   0.0         0.0      54.0      35.0
# 1960-01-04     0.0   0.0         0.0      54.0      36.0
# 1960-01-05     0.0   0.0         0.0      55.0      33.0
# ...            ...   ...         ...       ...       ...
# 2022-01-24     0.0   NaN         NaN      60.0      39.0
# 2022-01-25     0.0   NaN         NaN      57.0      43.0
# 2022-01-26     0.0   NaN         NaN      57.0      41.0
# 2022-01-27     0.0   NaN         NaN      67.0      39.0
# 2022-01-28     0.0   NaN         NaN      64.0      39.0
#
# [16859 rows x 5 columns]

# %% [markdown]
# filling missing values

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.016668
# snow          0.324990
# snow_depth    0.317634
# temp_max      0.000534
# temp_min      0.000593
# dtype: float64

# %%
core_weather['snow'].value_counts()
# Out:
# snow
# 0.0    11379
# 1.0        1
# Name: count, dtype: int64

# %%
del core_weather['snow']

# %%
core_weather
# Out:
#             precip  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01     0.0         0.0      49.0      30.0
# 1960-01-02     0.0         0.0      49.0      29.0
# 1960-01-03     0.0         0.0      54.0      35.0
# 1960-01-04     0.0         0.0      54.0      36.0
# 1960-01-05     0.0         0.0      55.0      33.0
# ...            ...         ...       ...       ...
# 2022-01-24     0.0         NaN      60.0      39.0
# 2022-01-25     0.0         NaN      57.0      43.0
# 2022-01-26     0.0         NaN      57.0      41.0
# 2022-01-27     0.0         NaN      67.0      39.0
# 2022-01-28     0.0         NaN      64.0      39.0
#
# [16859 rows x 4 columns]

# %%
core_weather[pd.isnull(core_weather['precip'])]
# Out:
#             precip  snow_depth  temp_max  temp_min
# DATE
# 1983-10-29     NaN         0.0      67.0      57.0
# 1983-10-30     NaN         0.0      70.0      63.0
# 1983-10-31     NaN         0.0      69.0      61.0
# 1983-11-12     NaN         0.0      63.0      55.0
# 1983-11-13     NaN         0.0      60.0      50.0
# ...            ...         ...       ...       ...
# 2013-12-15     NaN         NaN      58.0      33.0
# 2016-05-01     NaN         NaN      80.0      55.0
# 2016-05-02     NaN         NaN      68.0      53.0
# 2016-05-08     NaN         NaN      67.0      56.0
# 2017-10-28     NaN         NaN      68.0      50.0
#
# [281 rows x 4 columns]

# %%
core_weather.loc['1983-10-20':'1983-11-05',:]
# Out:
#             precip  snow_depth  temp_max  temp_min
# DATE
# 1983-10-20    0.00         0.0      73.0      52.0
# 1983-10-21    0.00         0.0      70.0      50.0
# 1983-10-22    0.00         0.0      70.0      50.0
# 1983-10-23    0.00         0.0      69.0      60.0
# 1983-10-24    0.00         0.0      73.0      58.0
# 1983-10-25    0.00         0.0      75.0      53.0
# 1983-10-26    0.00         0.0      79.0      53.0
# 1983-10-27    0.00         0.0      82.0      56.0
# 1983-10-28    0.00         0.0      74.0      56.0
# 1983-10-29     NaN         0.0      67.0      57.0
# 1983-10-30     NaN         0.0      70.0      63.0
# 1983-10-31     NaN         0.0      69.0      61.0
# 1983-11-01    0.26         0.0      69.0      60.0
# 1983-11-02    0.06         0.0      68.0      56.0
# 1983-11-03    0.00         0.0      68.0      56.0
# 1983-11-04    0.00         0.0      67.0      55.0
# 1983-11-05    0.00         0.0      66.0      51.0

# %%
core_weather['precip'].value_counts()
# Out:
# precip
# 0.00    13664
# 0.01      438
# 0.02      199
# 0.03      122
# 0.04      102
#         ...
# 1.29        1
# 1.73        1
# 1.05        1
# 1.38        1
# 1.02        1
# Name: count, Length: 176, dtype: int64

# %%
core_weather['precip']=core_weather['precip'].fillna(0)

# %%
core_weather
# Out:
#             precip  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01     0.0         0.0      49.0      30.0
# 1960-01-02     0.0         0.0      49.0      29.0
# 1960-01-03     0.0         0.0      54.0      35.0
# 1960-01-04     0.0         0.0      54.0      36.0
# 1960-01-05     0.0         0.0      55.0      33.0
# ...            ...         ...       ...       ...
# 2022-01-24     0.0         NaN      60.0      39.0
# 2022-01-25     0.0         NaN      57.0      43.0
# 2022-01-26     0.0         NaN      57.0      41.0
# 2022-01-27     0.0         NaN      67.0      39.0
# 2022-01-28     0.0         NaN      64.0      39.0
#
# [16859 rows x 4 columns]

# %%
del core_weather["snow_depth"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min
# DATE
# 1960-01-01     0.0      49.0      30.0
# 1960-01-02     0.0      49.0      29.0
# 1960-01-03     0.0      54.0      35.0
# 1960-01-04     0.0      54.0      36.0
# 1960-01-05     0.0      55.0      33.0
# ...            ...       ...       ...
# 2022-01-24     0.0      60.0      39.0
# 2022-01-25     0.0      57.0      43.0
# 2022-01-26     0.0      57.0      41.0
# 2022-01-27     0.0      67.0      39.0
# 2022-01-28     0.0      64.0      39.0
#
# [16859 rows x 3 columns]

# %%
core_weather[pd.isnull(core_weather['temp_min'])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20     0.0       NaN       NaN
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2013-06-16     0.0       NaN       NaN
# 2020-08-29     0.0       NaN       NaN
# 2020-09-08     0.0       NaN       NaN
# 2020-09-09     0.0       NaN       NaN

# %%
core_weather=core_weather.fillna(method='ffill')

# %%
core_weather
# Out:
#             precip  temp_max  temp_min
# DATE
# 1960-01-01     0.0      49.0      30.0
# 1960-01-02     0.0      49.0      29.0
# 1960-01-03     0.0      54.0      35.0
# 1960-01-04     0.0      54.0      36.0
# 1960-01-05     0.0      55.0      33.0
# ...            ...       ...       ...
# 2022-01-24     0.0      60.0      39.0
# 2022-01-25     0.0      57.0      43.0
# 2022-01-26     0.0      57.0      41.0
# 2022-01-27     0.0      67.0      39.0
# 2022-01-28     0.0      64.0      39.0
#
# [16859 rows x 3 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip      0.0
# temp_max    0.0
# temp_min    0.0
# dtype: float64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04', '1960-01-05',
#        '1960-01-06', '1960-01-07', '1960-01-08', '1960-01-09', '1960-01-10',
#        ...
#        '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-22', '2022-01-23',
#        '2022-01-24', '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28'],
#       dtype='object', name='DATE', length=16859)

# %%
core_weather.index=pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-22',
#                '2022-01-23', '2022-01-24', '2022-01-25', '2022-01-26',
#                '2022-01-27', '2022-01-28'],
#               dtype='datetime64[ns]', name='DATE', length=16859, freq=None)

# %%
core_weather.apply(lambda x: sum(x.isnull()))
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %% [markdown]
# analyze our weather data

# %%
core_weather[['temp_max','temp_min']].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1960    366
# 1961    365
# 1962    365
# 1963    365
# 1964    366
# 1965    365
# 1966    365
# 1967    365
# 1968    366
# 1969    365
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1983    184
# 1984    366
# 1985    365
# 1986    212
# 2000    365
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    365
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    364
# 2022     28
# Name: count, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()
# Out:
#       precip  temp_max  temp_min
# DATE
# 1960   14.01   24135.0   17973.0
# 1961   13.87   24202.0   17819.0
# 1962   22.47   23785.0   17880.0
# 1963   19.11   23470.0   18237.0
# 1964   16.83   23013.0   18637.0
# 1965   16.32   23181.0   18715.0
# 1966   13.11   23680.0   18991.0
# 1967   23.98   23433.0   18668.0
# 1968   17.19   23634.0   18859.0
# 1969   25.70   23276.0   18493.0
# 1970   25.31   23465.0   18653.0
# 1971   10.61   22897.0   18084.0
# 1972   16.27   23262.0   18757.0
# 1973   29.37   23155.0   18445.0
# 1974   16.87   23289.0   18400.0
# 1975   17.54   23174.0   18150.0
# 1976    8.64   23859.0   18325.0
# 1977   11.70   23970.0   18884.0
# 1978   22.57   24112.0   18980.0
# 1979   23.79   23899.0   19107.0
# 1980   13.58   24064.0   18855.0
# 1983    7.13   12658.0   10316.0
# 1984   16.03   23998.0   18966.0
# 1985    8.50   23249.0   18461.0
# 1986    0.00   14112.0   11516.0
# 2000   21.09   23773.0   17841.0
# 2001   22.84   23890.0   17895.0
# ...

# %%
core_weather['target']=core_weather.shift(-1)['temp_max']

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01     0.0      49.0      30.0    49.0
# 1960-01-02     0.0      49.0      29.0    54.0
# 1960-01-03     0.0      54.0      35.0    54.0
# 1960-01-04     0.0      54.0      36.0    55.0
# 1960-01-05     0.0      55.0      33.0    53.0
# ...            ...       ...       ...     ...
# 2022-01-24     0.0      60.0      39.0    57.0
# 2022-01-25     0.0      57.0      43.0    57.0
# 2022-01-26     0.0      57.0      41.0    67.0
# 2022-01-27     0.0      67.0      39.0    64.0
# 2022-01-28     0.0      64.0      39.0     NaN
#
# [16859 rows x 4 columns]

# %%
core_weather=core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01     0.0      49.0      30.0    49.0
# 1960-01-02     0.0      49.0      29.0    54.0
# 1960-01-03     0.0      54.0      35.0    54.0
# 1960-01-04     0.0      54.0      36.0    55.0
# 1960-01-05     0.0      55.0      33.0    53.0
# ...            ...       ...       ...     ...
# 2022-01-23     0.0      60.0      41.0    60.0
# 2022-01-24     0.0      60.0      39.0    57.0
# 2022-01-25     0.0      57.0      43.0    57.0
# 2022-01-26     0.0      57.0      41.0    67.0
# 2022-01-27     0.0      67.0      39.0    64.0
#
# [16858 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge
reg=Ridge(alpha=.1)

# %%
predictors=['precip','temp_max','temp_min']

# %%
train=core_weather.loc[:"2020-12-31"]

# %%
test=core_weather.loc["2021-01-01":]

# %%
reg.fit(train[predictors],train['target'])
# Out:
# Ridge(alpha=0.1)

# %%
predictions=reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(predictions,test['target'])
# Out:
# 3.4111699434528306

# %%
combined=pd.concat([test["target"],pd.Series(predictions, index=test.index)], axis=1)
combined.columns=['actual','predictions']

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    57.0    59.806024
# 2021-01-02    56.0    59.310181
# 2021-01-03    62.0    58.538685
# 2021-01-04    59.0    61.531814
# 2021-01-05    59.0    59.444266
# ...            ...          ...
# 2022-01-23    60.0    59.985714
# 2022-01-24    57.0    59.626333
# 2022-01-25    57.0    58.181680
# 2022-01-26    67.0    57.822299
# 2022-01-27    64.0    64.674302
#
# [391 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-2.20730384,  0.72113834,  0.17969047])

# %% [markdown]
# creating a function to make predictions

# %%
def create_predictions(predictors,core_weather,reg):
  train=core_weather.loc[:"2020-12-31"]
  test=core_weather.loc["2021-01-01":]
  reg.fit(train[predictors],train['target'])
  predictions=reg.predict(test[predictors])
  error=mean_absolute_error(predictions,test['target'])
  combined=pd.concat([test["target"],pd.Series(predictions, index=test.index)], axis=1)
  combined.columns=['actual','predictions']
  return error, combined

# %%
core_weather["month_max"]=core_weather["temp_max"].rolling(30).mean()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max
# DATE
# 1960-01-01     0.0      49.0      30.0    49.0        NaN
# 1960-01-02     0.0      49.0      29.0    54.0        NaN
# 1960-01-03     0.0      54.0      35.0    54.0        NaN
# 1960-01-04     0.0      54.0      36.0    55.0        NaN
# 1960-01-05     0.0      55.0      33.0    53.0        NaN
# ...            ...       ...       ...     ...        ...
# 2022-01-23     0.0      60.0      41.0    60.0  56.900000
# 2022-01-24     0.0      60.0      39.0    57.0  57.066667
# 2022-01-25     0.0      57.0      43.0    57.0  57.200000
# 2022-01-26     0.0      57.0      41.0    67.0  57.400000
# 2022-01-27     0.0      67.0      39.0    64.0  57.933333
#
# [16858 rows x 5 columns]

# %%
core_weather["month_day_max"]=core_weather["temp_max"]/core_weather["temp_max"]

# %%
core_weather["max_min"]=core_weather["temp_max"]/core_weather["temp_min"]

# %%
predictors=['precip','temp_max','temp_min','month_max','month_day_max','max_min']

# %%
core_weather=core_weather.iloc[30:,:].copy()

# %%
errors,combined=create_predictions(predictors,core_weather,reg)

# %%
errors
# Out:
# 3.3535970292203547

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["monthly_avg"] = core_weather['temp_max'].groupby(core_weather.index.month).apply(lambda x: x.expanding(1).mean()).reset_index(level=0, drop=True)

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1960-01-31    0.00      59.0      46.0    62.0  55.566667            1.0
# 1960-02-01    0.81      62.0      51.0    59.0  56.000000            1.0
# 1960-02-02    0.00      59.0      43.0    59.0  56.166667            1.0
# 1960-02-03    0.20      59.0      47.0    60.0  56.333333            1.0
# 1960-02-04    0.16      60.0      42.0    60.0  56.500000            1.0
# ...            ...       ...       ...     ...        ...            ...
# 2022-01-23    0.00      60.0      41.0    60.0  56.900000            1.0
# 2022-01-24    0.00      60.0      39.0    57.0  57.066667            1.0
# 2022-01-25    0.00      57.0      43.0    57.0  57.200000            1.0
# 2022-01-26    0.00      57.0      41.0    67.0  57.400000            1.0
# 2022-01-27    0.00      67.0      39.0    64.0  57.933333            1.0
#
#              max_min  monthly_avg
# DATE
# 1960-01-31  1.282609    59.000000
# ...

# %%
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.day_of_year).apply(lambda x: x.expanding(1).mean()).reset_index(level=0, drop=True)

# %%
error, combined = create_predictions(predictors, core_weather, reg) # Call create_predictions before modifying core_weather
error

core_weather["monthly_avg"] = core_weather['temp_max'].groupby(core_weather.index.month).apply(lambda x: x.expanding(1).mean()).reset_index(level=0, drop=True)
core_weather["day_of_year_avg"] = core_weather["temp_max"].groupby(core_weather.index.day_of_year).apply(lambda x: x.expanding(1).mean()).reset_index(level=0, drop=True)

error, combined = create_predictions(predictors + ["monthly_avg", "day_of_year_avg"], core_weather, reg) # Now call it with updated dataframe
error
# Out:
# 3.306348278326766

# %%
reg.coef_
# Out:
# array([-1.03603247,  0.62267771,  0.04209172,  0.09991632,  0.        ,
#         0.06276373,  0.1450078 ,  0.08306972])

# %%
core_weather.corr()["target"]
# Out:
# precip            -0.205413
# temp_max           0.821650
# temp_min           0.596016
# target             1.000000
# month_max          0.686842
# month_day_max           NaN
# max_min            0.045228
# monthly_avg        0.689805
# day_of_year_avg    0.712334
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending=False).head(10)
# Out:
#             actual  predictions       diff
# DATE
# 2021-01-17    83.0    68.497143  14.502857
# 2021-04-01    62.0    75.520319  13.520319
# 2021-05-07    81.0    67.646953  13.353047
# 2021-02-21    77.0    64.195324  12.804676
# 2021-10-16    66.0    78.799831  12.799831
# 2021-02-22    84.0    71.272297  12.727703
# 2021-03-30    82.0    69.995059  12.004941
# 2021-07-07    79.0    67.371741  11.628259
# 2021-10-04    69.0    80.474708  11.474708
# 2021-03-29    74.0    62.547937  11.452063
